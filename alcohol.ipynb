# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt   
import seaborn as sns

# %%
alcohol_df = pd.read_csv('D:\python\project\pro1.csv');
alcohol_df.head()
# Out:
#    year              region  wine  beer  vodka  champagne  brandy
# 0  1998  Republic of Adygea   1.9   8.8    3.4        0.3     0.1
# 1  1998          Altai Krai   3.3  19.2   11.3        1.1     0.1
# 2  1998         Amur Oblast   2.1  21.2   17.3        0.7     0.4
# 3  1998  Arkhangelsk Oblast   4.3  10.6   11.7        0.4     0.3
# 4  1998    Astrakhan Oblast   2.9  18.0    9.5        0.8     0.2

# %%
alcohol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       1615 non-null   int64
#  1   region     1615 non-null   object
#  2   wine       1552 non-null   float64
#  3   beer       1557 non-null   float64
#  4   vodka      1554 non-null   float64
#  5   champagne  1552 non-null   float64
#  6   brandy     1549 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 88.4+ KB

# %%
des=alcohol_df.describe();
des
# Out:
#               year         wine         beer        vodka    champagne  \
# count  1615.000000  1552.000000  1557.000000  1554.000000  1552.000000
# mean   2007.000000     5.628144    51.260148    11.818694     1.313177
# std       5.478922     2.813208    25.372821     5.128806     0.797956
# min    1998.000000     0.100000     0.400000     0.050000     0.100000
# 25%    2002.000000     3.575000    32.400000     8.300000     0.800000
# 50%    2007.000000     5.400000    49.970000    11.500000     1.200000
# 75%    2012.000000     7.377500    67.400000    15.000000     1.665000
# max    2016.000000    18.100000   207.300000    40.600000     5.560000
#
#             brandy
# count  1549.000000
# mean      0.526998
# std       0.400201
# min       0.000000
# 25%       0.200000
# 50%       0.400000
# 75%       0.700000
# max       2.300000

# %%
alcohol_df.duplicated().sum()
# Out:
# 0

# %%
dummy=alcohol_df.isnull().sum();
dummy
# Out:
# year          0
# region        0
# wine         63
# beer         58
# vodka        61
# champagne    63
# brandy       66
# dtype: int64

# %%
sns.distplot(alcohol_df['wine'])
# Out:
# c:\Users\Sainu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='wine', ylabel='Density'>

# %%
plt.hist(alcohol_df.wine)
# Out:
# (array([128., 272., 392., 358., 227., 107.,  38.,  20.,   6.,   4.]),
#  array([ 0.1,  1.9,  3.7,  5.5,  7.3,  9.1, 10.9, 12.7, 14.5, 16.3, 18.1]),
#  <BarContainer object of 10 artists>)

# %%
integer_float=alcohol_df.select_dtypes(['int64','float64'])
integer_float
# Out:
#       year  wine  beer  vodka  champagne  brandy
# 0     1998   1.9   8.8    3.4        0.3     0.1
# 1     1998   3.3  19.2   11.3        1.1     0.1
# 2     1998   2.1  21.2   17.3        0.7     0.4
# 3     1998   4.3  10.6   11.7        0.4     0.3
# 4     1998   2.9  18.0    9.5        0.8     0.2
# ...    ...   ...   ...    ...        ...     ...
# 1610  2016   5.0  42.3    7.7        0.7     0.4
# 1611  2016   3.9  34.0   11.6        1.8     1.1
# 1612  2016   4.3  56.1    8.2        1.8     0.5
# 1613  2016   4.5  75.8    8.2        1.7     1.3
# 1614  2016  10.2  38.0    8.9        1.4     1.0
#
# [1615 rows x 6 columns]

# %%
integer_float.skew()
# Out:
# year         0.000000
# wine         0.691864
# beer         0.674861
# vodka        0.589135
# champagne    1.612276
# brandy       1.387473
# dtype: float64

# %%
alcohol_df['wine']=alcohol_df['wine'].fillna(alcohol_df['wine'].mean())

# %%
alcohol_df['wine'].isna().sum()
# Out:
# 0

# %%
sns.distplot(alcohol_df['beer'])
# Out:
# c:\Users\Sainu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='beer', ylabel='Density'>

# %%
alcohol_df['beer']=alcohol_df['beer'].fillna(alcohol_df['beer'].mean())

# %%
alcohol_df['beer'].isna().sum()
# Out:
# 0

# %%
sns.distplot(alcohol_df['vodka'])
# Out:
# c:\Users\Sainu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='vodka', ylabel='Density'>

# %%
alcohol_df['vodka']=alcohol_df['vodka'].fillna(alcohol_df['vodka'].mean())

# %%
alcohol_df['vodka'].isna().sum()
# Out:
# 0

# %%
sns.distplot(alcohol_df['champagne'])
# Out:
# c:\Users\Sainu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='champagne', ylabel='Density'>

# %%
alcohol_df['champagne']=alcohol_df['champagne'].fillna(alcohol_df['champagne'].median())

# %%
alcohol_df['champagne'].isna().sum()
# Out:
# 0

# %%
sns.distplot(alcohol_df['brandy'])
# Out:
# c:\Users\Sainu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='brandy', ylabel='Density'>

# %%
alcohol_df['brandy']=alcohol_df['brandy'].fillna(alcohol_df['brandy'].median())

# %%
alcohol_df['brandy'].isna().sum()
# Out:
# 0

# %%
new_df=alcohol_df.isnull().sum()
new_df
# Out:
# year         0
# region       0
# wine         0
# beer         0
# vodka        0
# champagne    0
# brandy       0
# dtype: int64

# %%
sns.relplot(x='year',y='wine',data=alcohol_df,kind='line')

# %%
sns.relplot(x='year',y='beer',kind='line',data=alcohol_df)

# %%
sns.relplot(x='year',y='champagne',data=alcohol_df,kind='line')

# %%
sns.relplot(x='year',y='brandy',kind='line',data=alcohol_df)

# %%
sns.relplot(x='year',y='vodka',kind='line',data=alcohol_df)
